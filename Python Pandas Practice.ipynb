# %%
import pandas as pd
import numpy as np

# %%
#pd.options.display.max_columns = 50  
#pd.options.display.max_rows = 16300     
#pd.options.display.max_colwidth = 10000
#pd.options.display.precision = 3

# %%
original = pd.read_csv("small.csv")
original
# Out:
#         Dates   Close    Volume Symbol
# 0  03-10-2016   31.50  14070500   CSCO
# 1  03-10-2016  112.52  21701800   AAPL
# 2  03-10-2016   57.42  19189500   MSFT

# %%
upd_original = original.copy()
upd_original["Name"] = ["Alice","Bob","Clair"]
upd_original["open_value"] = [70.5,150,90.5]
upd_original["mid_value"] = [51,131.26,73.96]
upd_original["Bonus"] = [0,0,0]
#upd_original.to_csv("output_small.csv", index = False)
upd_original
# Out:
#         Dates   Close    Volume Symbol   Name  open_value  mid_value  Bonus
# 0  03-10-2016   31.50  14070500   CSCO  Alice        70.5      51.00      0
# 1  03-10-2016  112.52  21701800   AAPL    Bob       150.0     131.26      0
# 2  03-10-2016   57.42  19189500   MSFT  Clair        90.5      73.96      0

# %% [markdown]
# __Note:__ The small.csv file contain data of type DataFrame.So,we can not add a new columns using pandas Series.

# %%
col = list(upd_original.columns.values)
a = pd.Series(col)
b = pd.Series(["New_Column1","New_Column2","New_Column3"],index = [8, 9, 10])
a.append(b)
# Out:
# 0           Dates
# 1           Close
# 2          Volume
# 3          Symbol
# 4            Name
# 5      open_value
# 6       mid_value
# 7           Bonus
# 8     New_Column1
# 9     New_Column2
# 10    New_Column3
# dtype: object

# %%
new_column = upd_original.open_value * upd_original.mid_value
upd_original["new_column"] = new_column
upd_original
# Out:
#         Dates   Close    Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  14070500   CSCO  Alice        70.5      51.00      0
# 1  03-10-2016  112.52  21701800   AAPL    Bob       150.0     131.26      0
# 2  03-10-2016   57.42  19189500   MSFT  Clair        90.5      73.96      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38

# %%
upd_original.iloc[:3,[2]] = 9999999
upd_original.iloc[:3,[6]] = 400.0
upd_original
# Out:
#         Dates   Close   Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  9999999   CSCO  Alice        70.5      400.0      0
# 1  03-10-2016  112.52  9999999   AAPL    Bob       150.0      400.0      0
# 2  03-10-2016   57.42  9999999   MSFT  Clair        90.5      400.0      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38

# %%
upd_original.loc[:3,"Volume"] = 9999999
upd_original.loc[:3,"mid_value"] = 400.0
upd_original
# Out:
#         Dates   Close   Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  9999999   CSCO  Alice        70.5      400.0      0
# 1  03-10-2016  112.52  9999999   AAPL    Bob       150.0      400.0      0
# 2  03-10-2016   57.42  9999999   MSFT  Clair        90.5      400.0      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38

# %%
k = {"Dates":"03-10-2016","Close":0,"Volume":0,"Symbol":None,"Name":None,"open_value":0,"mid_value":0,"Volume":0,"Bonus":0,"new_column":0}
upd_add_row = upd_original.append(k,ignore_index = True).copy()
upd_add_row
# Out:
#         Dates   Close   Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  9999999   CSCO  Alice        70.5      400.0      0
# 1  03-10-2016  112.52  9999999   AAPL    Bob       150.0      400.0      0
# 2  03-10-2016   57.42  9999999   MSFT  Clair        90.5      400.0      0
# 3  03-10-2016    0.00        0   None   None         0.0        0.0      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38
# 3        0.00

# %%
ret_upd_Original = upd_add_row.drop([3]).copy()
ret_upd_Original
# Out:
#         Dates   Close   Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  9999999   CSCO  Alice        70.5      400.0      0
# 1  03-10-2016  112.52  9999999   AAPL    Bob       150.0      400.0      0
# 2  03-10-2016   57.42  9999999   MSFT  Clair        90.5      400.0      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38

# %% [markdown]
# ## Checking the files

# %%
original
# Out:
#         Dates   Close    Volume Symbol
# 0  03-10-2016   31.50  14070500   CSCO
# 1  03-10-2016  112.52  21701800   AAPL
# 2  03-10-2016   57.42  19189500   MSFT

# %%
upd_original
# Out:
#         Dates   Close   Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  9999999   CSCO  Alice        70.5      400.0      0
# 1  03-10-2016  112.52  9999999   AAPL    Bob       150.0      400.0      0
# 2  03-10-2016   57.42  9999999   MSFT  Clair        90.5      400.0      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38

# %%
upd_add_row
# Out:
#         Dates   Close   Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  9999999   CSCO  Alice        70.5      400.0      0
# 1  03-10-2016  112.52  9999999   AAPL    Bob       150.0      400.0      0
# 2  03-10-2016   57.42  9999999   MSFT  Clair        90.5      400.0      0
# 3  03-10-2016    0.00        0   None   None         0.0        0.0      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38
# 3        0.00

# %%
ret_upd_Original
# Out:
#         Dates   Close   Volume Symbol   Name  open_value  mid_value  Bonus  \
# 0  03-10-2016   31.50  9999999   CSCO  Alice        70.5      400.0      0
# 1  03-10-2016  112.52  9999999   AAPL    Bob       150.0      400.0      0
# 2  03-10-2016   57.42  9999999   MSFT  Clair        90.5      400.0      0
#
#    new_column
# 0     3595.50
# 1    19689.00
# 2     6693.38

# %%
original_ac = pd.read_csv("autocars.csv")
#original_ac

# %%
original_ac.head(3)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0

# %%
original_ac.tail(3)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
original_ac.groupby(["company"])["price"].max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
original_ac["price"].max()
# Out:
# 45400.0

# %%
original_ac.loc[original_ac["price"].idxmax()]
# Out:
# index                          47
# company             mercedes-benz
# body-style                hardtop
# wheel-base                    112
# length                      199.2
# engine-type                  ohcv
# num-of-cylinders            eight
# horsepower                    184
# average-mileage                14
# price                       45400
# Name: 35, dtype: object

# %%
original_ac.iloc[original_ac["price"].idxmax(),[1]]
# Out:
# company    mercedes-benz
# Name: 35, dtype: object

# %%
original_ac[3:7]
# Out:
#    index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3      3    audi      sedan        99.8   176.6         ohc             four
# 4      4    audi      sedan        99.4   176.6         ohc             five
# 5      5    audi      sedan        99.8   177.3         ohc             five
# 6      6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3         102               24  13950.0
# 4         115               18  17450.0
# 5         110               19  15250.0
# 6         110               19  18920.0

# %%
original_ac.loc[original_ac["company"] == "audi"]
# Out:
#    index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3      3    audi      sedan        99.8   176.6         ohc             four
# 4      4    audi      sedan        99.4   176.6         ohc             five
# 5      5    audi      sedan        99.8   177.3         ohc             five
# 6      6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3         102               24  13950.0
# 4         115               18  17450.0
# 5         110               19  15250.0
# 6         110               19  18920.0

# %%
original_ac["company"].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# mitsubishi       4
# volkswagen       4
# mercedes-benz    4
# audi             4
# jaguar           3
# chevrolet        3
# isuzu            3
# alfa-romero      3
# honda            3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
original_ac.sort_values(["price"])
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 13     16      chevrolet  hatchback        88.4   141.1           l
# 27     36          mazda  hatchback        93.1   159.1         ohc
# 48     66         toyota  hatchback        95.7   158.7         ohc
# 36     49     mitsubishi  hatchback        93.7   157.3         ohc
# 28     37          mazda  hatchback        93.1   159.1         ohc
# ..    ...            ...        ...         ...     ...         ...
# 11     14            bmw      sedan       103.5   193.8         ohc
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
# 22     31          isuzu      sedan        94.5   155.9         ohc
# 23     32          isuzu      sedan        94.5   155.9         ohc
# 47     63        porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 13            three          48               47   5151.0
# ...

# %%
original_ac.groupby(["company"])["average-mileage"].mean()
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %%
original_ac.groupby(["company"])["average-mileage"].describe()[["mean"]]
# Out:
#                     mean
# company
# alfa-romero    20.333333
# audi           20.000000
# bmw            19.000000
# chevrolet      41.000000
# dodge          31.000000
# honda          26.333333
# isuzu          33.333333
# jaguar         14.333333
# mazda          28.000000
# mercedes-benz  18.000000
# mitsubishi     29.500000
# nissan         31.400000
# porsche        17.000000
# toyota         28.714286
# volkswagen     31.750000
# volvo          23.000000

# %%
frame = pd.DataFrame(np.random.randn(4, 3),columns = list('bde'),index = ["Utah","Ohio","Texas","Oregon"])
frame
# Out:
#                b         d         e
# Utah    0.299584  0.075553 -0.551945
# Ohio    0.446384  1.090667  0.616634
# Texas  -1.111127  0.275675 -0.318524
# Oregon  0.179052 -0.425130  0.077052

# %%
def color(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    if (val < 0):
        color = "green" 
    elif (val > 0):
        color = "blue"
    else:
        color = "black"
    return "color:%s" %color

# %%
frame.style.applymap(color, subset = ["d","e"])
# Out:
# <style  type="text/css" >
#     #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row0_col1 {
#             color: blue;
#         }    #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row0_col2 {
#             color: green;
#         }    #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row1_col1 {
#             color: blue;
#         }    #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row1_col2 {
#             color: blue;
#         }    #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row2_col1 {
#             color: blue;
#         }    #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row2_col2 {
#             color: green;
#         }    #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row3_col1 {
#             color: green;
#         }    #T_a2e637b8_dbec_11e9_b3fa_f43909e8c6e4row3_col2 {
#             color: blue;
# ...

# %%
given = pd.DataFrame({"order_id":[1,1,1,2,3,3], "price":[5,6,1,20,2,5]}) 
given
# Out:
#    order_id  price
# 0         1      5
# 1         1      6
# 2         1      1
# 3         2     20
# 4         3      2
# 5         3      5

# %% [markdown]
# __Method 1:__

# %%
new = given[["order_id","price"]].groupby(["order_id"]).agg(["mean"])
new
# Out:
#          price
#           mean
# order_id
# 1          4.0
# 2         20.0
# 3          3.5

# %%
given.merge(new,left_on = "order_id",right_index = True)
# Out:
# C:\Users\harik\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
#    order_id  price  (price, mean)
# 0         1      5            4.0
# 1         1      6            4.0
# 2         1      1            4.0
# 3         2     20           20.0
# 4         3      2            3.5
# 5         3      5            3.5

# %% [markdown]
# __Method 2:__

# %%
given.groupby(["order_id"]).price.sum()
# Out:
# order_id
# 1    12
# 2    20
# 3     7
# Name: price, dtype: int64

# %%
given["sum_price"] = given.groupby(["order_id"]).price.transform(sum)
given
# Out:
#    order_id  price  sum_price
# 0         1      5         12
# 1         1      6         12
# 2         1      1         12
# 3         2     20         20
# 4         3      2          7
# 5         3      5          7

# %%
df = pd.DataFrame({'Y': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})
df
# Out:
#    Y
# 0  7
# 1  2
# 2  0
# 3  3
# 4  4
# 5  2
# 6  5
# 7  0
# 8  3
# 9  4

# %%
X = []
i = 0
for index, row in df.iterrows():
    if (row["Y"] != 0):
        i+=1
    else:
        i = 0
    X.append(i)
print(X)
# Out:
# [1, 2, 0, 1, 2, 3, 4, 0, 1, 2]

# %%
df_X = pd.DataFrame({"X":X})
df_X
# Out:
#    X
# 0  1
# 1  2
# 2  0
# 3  1
# 4  2
# 5  3
# 6  4
# 7  0
# 8  1
# 9  2

# %%
pd.concat([df,df_X],axis = 1)
# Out:
#    Y  X
# 0  7  1
# 1  2  2
# 2  0  0
# 3  3  1
# 4  4  2
# 5  2  3
# 6  5  4
# 7  0  0
# 8  3  1
# 9  4  2

# %% [markdown]
# ## From single series object

# %%
names = ["Normen","Blanka","Tim"]

x = pd.Series(names)  

dataframe = {"Names":x}
df0 = pd.DataFrame(dataframe) 
df0
# Out:
#     Names
# 0  Normen
# 1  Blanka
# 2     Tim

# %%
df0["Age"] = [28,27,24]
df0["country"] = ["RU","IND","PAK"]
df0
# Out:
#     Names  Age country
# 0  Normen   28      RU
# 1  Blanka   27     IND
# 2     Tim   24     PAK

# %% [markdown]
# ## From list of dicts

# %%
dt = [{"Player":"X","Age":25,"Country":"UAE"},{"Player":"Y","Age":28,"Country":"SA"}]
df1 = pd.DataFrame(dt, index = [0,1])
df1
# Out:
#   Player  Age Country
# 0      X   25     UAE
# 1      Y   28      SA

# %% [markdown]
# ##  From dictionary of series objects

# %%
dt = {"Player": pd.Series(["Tom","James","Atom"]),"Age": pd.Series([32,23,29]),"Country": pd.Series(["AFG","SL","NZ"])}
df2 =  pd.DataFrame(dt)
df2
# Out:
#   Player  Age Country
# 0    Tom   32     AFG
# 1  James   23      SL
# 2   Atom   29      NZ

# %% [markdown]
# ## From two dimenesional numpy array

# %%
array1 = np.array([["Thomas",22,"USA",4,33], ["Finn",25,"AUS",2,34], ["John",28,"NL",6,27]])
df3 = pd.DataFrame(array1,columns=["Name","Age","Country","Rank","Matchs"],index=[0,1,2])
df3
# Out:
#      Name Age Country Rank Matchs
# 0  Thomas  22     USA    4     33
# 1    Finn  25     AUS    2     34
# 2    John  28      NL    6     27

# %% [markdown]
# ## From numpy structured array

# %%
array2 = np.array([("Tony",24,"DE",1,35),("Stefan",31,"FR",3,24),("Henry",28,"UK",5,29)], dtype=[("Name","U10"),("Age","<i4"),("Country","<U10"),("Rank","<i4"),("Matchs","<i4")])
df4 = pd.DataFrame(array2,index=[3,4,5])
df4
# Out:
#      Name  Age Country  Rank  Matchs
# 3    Tony   24      DE     1      35
# 4  Stefan   31      FR     3      24
# 5   Henry   28      UK     5      29

# %%
pd.concat([df3,df4])
# Out:
#      Name Age Country Rank Matchs
# 0  Thomas  22     USA    4     33
# 1    Finn  25     AUS    2     34
# 2    John  28      NL    6     27
# 3    Tony  24      DE    1     35
# 4  Stefan  31      FR    3     24
# 5   Henry  28      UK    5     29

# %%
nrows, ncols = 100000, 100
rng = np.random.RandomState(42)
df1, df2, df3, df4 = (pd.DataFrame(rng.rand(nrows, ncols)) for i in range(4))

# %% [markdown]
# ## Simple Sum:

# %%
df1 + df2 + df3 + df4
# Out:
#              0         1         2         3         4         5         6   \
# 0      2.456085  2.240325  2.189299  2.796486  0.997756  1.857199  0.836188
# 1      1.930732  1.325833  2.100320  1.031509  2.216550  2.322945  2.221711
# 2      2.961585  1.241173  1.292687  1.559529  3.244460  1.727601  1.508593
# 3      1.325278  2.311100  3.153195  2.428513  2.468706  2.168389  1.036675
# 4      1.107165  1.998018  2.171741  3.011473  2.403474  1.785172  1.148053
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.948321  1.751224  2.276621  2.203974  2.752196  1.811677  1.544824
# 99996  2.249443  2.248954  2.840738  2.278969  1.552147  1.613808  2.537029
# 99997  1.942065  2.352778  1.104218  1.777017  2.159435  1.715014  2.424385
# 99998  2.681177  0.958664  2.867072  1.127300  1.277971  1.268119  1.756763
# 99999  2.300429  2.501596  2.385804  1.518952  2.691974  2.580092  2.047616
#
# ...

# %% [markdown]
# ## Pandas add() method:

# %%
a = df1.add(df2)
a
# Out:
#              0         1         2         3         4         5         6   \
# 0      1.301078  1.333176  1.603463  1.360130  0.484844  1.144815  0.178822
# 1      0.746596  1.127358  1.218888  0.828092  1.490152  1.229622  0.429451
# 2      1.617828  0.134042  0.254313  1.057008  1.464738  0.661747  0.782577
# 3      0.421140  1.442721  1.433321  1.400884  1.307772  1.183608  0.540550
# 4      0.898077  1.617197  1.157995  1.466456  1.121863  1.118848  0.857809
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.045469  1.070759  0.909209  0.728634  0.996060  1.300733  0.917771
# 99996  1.017933  0.946832  1.180836  1.096137  0.480894  0.704690  1.656817
# 99997  1.210628  1.000250  0.157345  1.109083  0.806835  0.515458  1.358310
# 99998  1.685482  0.363327  1.254268  0.657311  0.647627  0.234716  1.114813
# 99999  0.834697  0.742728  0.943514  1.153803  1.595564  1.415779  0.850241
#
# ...

# %%
b = a.add(df3)
b
# Out:
#              0         1         2         3         4         5         6   \
# 0      1.682863  2.217455  2.054043  2.249333  0.885022  1.474714  0.553742
# 1      1.322563  1.184762  1.539690  1.002837  2.198749  1.394696  1.281751
# 2      2.171304  0.791059  0.976173  1.115873  2.282824  1.544071  1.416285
# 3      1.262950  2.181698  2.202042  1.753605  1.762171  2.099259  0.705449
# 4      0.967494  1.987647  1.487876  2.348596  1.810117  1.511882  1.146305
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.698908  1.648105  1.734426  1.509214  1.913140  1.513634  1.511747
# 99996  1.581729  1.381208  2.010145  1.717128  1.107256  1.084151  2.100907
# 99997  1.632944  1.444848  0.967700  1.507291  1.654035  1.270273  1.763278
# 99998  2.021831  0.883623  1.979226  1.034128  1.046252  1.044712  1.749797
# 99999  1.355186  1.672470  1.644675  1.232916  2.072632  1.983905  1.543548
#
# ...

# %%
Sum = b.add(df4)
Sum
# Out:
#              0         1         2         3         4         5         6   \
# 0      2.456085  2.240325  2.189299  2.796486  0.997756  1.857199  0.836188
# 1      1.930732  1.325833  2.100320  1.031509  2.216550  2.322945  2.221711
# 2      2.961585  1.241173  1.292687  1.559529  3.244460  1.727601  1.508593
# 3      1.325278  2.311100  3.153195  2.428513  2.468706  2.168389  1.036675
# 4      1.107165  1.998018  2.171741  3.011473  2.403474  1.785172  1.148053
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.948321  1.751224  2.276621  2.203974  2.752196  1.811677  1.544824
# 99996  2.249443  2.248954  2.840738  2.278969  1.552147  1.613808  2.537029
# 99997  1.942065  2.352778  1.104218  1.777017  2.159435  1.715014  2.424385
# 99998  2.681177  0.958664  2.867072  1.127300  1.277971  1.268119  1.756763
# 99999  2.300429  2.501596  2.385804  1.518952  2.691974  2.580092  2.047616
#
# ...

# %% [markdown]
# ## Pandas eval() method:

# %%
pd.eval("df1 + df2 + df3 + df4")
# Out:
#              0         1         2         3         4         5         6   \
# 0      2.456085  2.240325  2.189299  2.796486  0.997756  1.857199  0.836188
# 1      1.930732  1.325833  2.100320  1.031509  2.216550  2.322945  2.221711
# 2      2.961585  1.241173  1.292687  1.559529  3.244460  1.727601  1.508593
# 3      1.325278  2.311100  3.153195  2.428513  2.468706  2.168389  1.036675
# 4      1.107165  1.998018  2.171741  3.011473  2.403474  1.785172  1.148053
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.948321  1.751224  2.276621  2.203974  2.752196  1.811677  1.544824
# 99996  2.249443  2.248954  2.840738  2.278969  1.552147  1.613808  2.537029
# 99997  1.942065  2.352778  1.104218  1.777017  2.159435  1.715014  2.424385
# 99998  2.681177  0.958664  2.867072  1.127300  1.277971  1.268119  1.756763
# 99999  2.300429  2.501596  2.385804  1.518952  2.691974  2.580092  2.047616
#
# ...

# %%
# %%timeit -n 10
names = ["Normen","Blanka","Tim"]

x = pd.Series(names)  

dataframe = {"Names":x}
df0 = pd.DataFrame(dataframe) 
df0
# Out:
# 499 µs ± 165 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
dt = [{"Player":"X","Age":25,"Country":"UAE"},{"Player":"Y","Age":28,"Country":"SA"}]
df1 = pd.DataFrame(dt, index=[0,1])
df1
# Out:
# 815 µs ± 160 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# __Comment:__ As observed, from above two blocks forming a dataframe from a series taking less time when compared to forming a dataframe from list of dictionaries.From this we can say that as the size of dataframe increases meaning memory allocation differs then time of execution also increases.
#                     __Tradeoff between Memory,Time and size__

# %%
Input = pd.read_csv("population_data.csv")
#Input

# %%
Input["sex"].value_counts()
# Out:
# Male      10860
# Female     5421
# Name: sex, dtype: int64

# %%
Input.groupby("sex")["age"].mean()
# Out:
# sex
# Female    37.066593
# Male      39.616483
# Name: age, dtype: float64

# %%
Input[["age","sex"]].groupby(["sex"]).agg(["count","min","mean","max"])
# Out:
#           age
#         count min       mean max
# sex
# Female   5421  17  37.066593  90
# Male    10860  17  39.616483  90

# %%
Per_Citizens = Input["native_country"].value_counts(normalize=True) * (100)
Per_Citizens
# Out:
# United-States                 91.597426
# Mexico                         1.924158
# Philippines                    0.605985
# Puerto-Rico                    0.437309
# Germany                        0.431061
# Canada                         0.381083
# India                          0.318611
# El-Salvador                    0.306116
# China                          0.293622
# Cuba                           0.268632
# England                        0.231149
# South                          0.218654
# Dominican-Republic             0.206160
# Italy                          0.199913
# Haiti                          0.193665
# Japan                          0.187418
# Portugal                       0.187418
# Poland                         0.168676
# Columbia                       0.162429
# Jamaica                        0.156182
# Guatemala                      0.149934
# Greece                         0.124945
# Vietnam                        0.118698
# ...

# %%
Per_Citizens["Germany"]
# Out:
# 0.43106141063284814

# %%
Per_Citizens["United-States"]
# Out:
# 91.59742612606985

# %%
Input.groupby("class")["age"].mean()
# Out:
# class
# <=50K.    37.048010
# >50K.     44.326833
# Name: age, dtype: float64

# %%
Input.groupby("class")["age"].std()
# Out:
# class
# <=50K.    14.268633
# >50K.     10.641164
# Name: age, dtype: float64

# %%
a = Input.filter(items=["class","education"]).copy()
a
# Out:
#         class     education
# 0      <=50K.          11th
# 1      <=50K.       HS-grad
# 2       >50K.    Assoc-acdm
# 3       >50K.  Some-college
# 4      <=50K.  Some-college
# ...       ...           ...
# 16276  <=50K.     Bachelors
# 16277  <=50K.       HS-grad
# 16278  <=50K.     Bachelors
# 16279  <=50K.     Bachelors
# 16280   >50K.     Bachelors
#
# [16281 rows x 2 columns]

# %%
b = a.loc[a["class"] == ">50K."].copy()
b
# Out:
#        class     education
# 2      >50K.    Assoc-acdm
# 3      >50K.  Some-college
# 7      >50K.   Prof-school
# 10     >50K.       HS-grad
# 14     >50K.       HS-grad
# ...      ...           ...
# 16254  >50K.       Masters
# 16255  >50K.       Masters
# 16261  >50K.   Prof-school
# 16265  >50K.       Masters
# 16280  >50K.     Bachelors
#
# [3846 rows x 2 columns]

# %%
b.education.unique()
# Out:
# array(['Assoc-acdm', 'Some-college', 'Prof-school', 'HS-grad', 'Masters',
#        'Doctorate', 'Bachelors', 'Assoc-voc', '9th', '10th', '7th-8th',
#        '11th', '5th-6th', '1st-4th', '12th', 'Preschool'], dtype=object)

# %%
out = [ ]
check = ["HS-grad","Some-college","Bachelors","Prof-school","Assoc-acdm","Assoc-voc","Masters","Doctorate","9th","10th","7th-8th","11th","12th"]
#check = ["1st-4th","5th-6th","Preschool"]
for index, row in b.iterrows():
    if (row["education"] not in check):
        out.append("False")
    else:
        out.append("True")

b["Output"] = out

# %%
b
# Out:
#        class     education Output
# 2      >50K.    Assoc-acdm   True
# 3      >50K.  Some-college   True
# 7      >50K.   Prof-school   True
# 10     >50K.       HS-grad   True
# 14     >50K.       HS-grad   True
# ...      ...           ...    ...
# 16254  >50K.       Masters   True
# 16255  >50K.       Masters   True
# 16261  >50K.   Prof-school   True
# 16265  >50K.       Masters   True
# 16280  >50K.     Bachelors   True
#
# [3846 rows x 3 columns]

# %%
check=["HS-grad","Some-college","Bachelors","Prof-school","Assoc-acdm","Assoc-voc","Masters","Doctorate","9th","10th","7th-8th","11th","12th"]
#check = ["1st-4th","5th-6th","Preschool"]
for index, row in b.iterrows():
    if (row["education"] in check):
        continue
    else:
        print(index,"False")
        break
# Out:
# 566 False

# %%
check=["HS-grad","Some-college","Bachelors","Prof-school","Assoc-acdm","Assoc-voc","Masters","Doctorate","9th","10th","7th-8th","11th","12th"]
#check = ["1st-4th","5th-6th","Preschool"]
Input.loc[Input["class"]==">50K."]["education"].isin(check).all()
# Out:
# False

# %%
Input[["race","sex","age"]].groupby(["race","sex"]).agg(["count","min","max","mean","std","unique"])
# Out:
#                             age                                \
#                           count min max       mean        std
# race               sex
# Amer-Indian-Eskimo Female    66  17  60  34.651515  12.266894
#                    Male      93  17  75  36.537634  11.005492
# Asian-Pac-Islander Female   171  18  81  36.807018  13.255993
#                    Male     309  18  90  38.815534  12.710371
# Black              Female   753  17  73  38.013280  12.945460
#                    Male     808  17  81  38.388614  13.327352
# Other              Female    46  17  64  30.108696  10.263697
#                    Male      89  18  67  36.101124  12.603251
# White              Female  4385  17  90  37.023489  14.698216
#                    Male    9561  17  90  39.808807  13.553669
#
#
#                                                                       unique
# race               sex
# Amer-Indian-Eskimo Female  [19, 50, 57, 53, 48, 36, 41, 18, 27, 20, 22, 4...
# ...

# %%
Input.groupby(["race","sex"])["age"].describe()[["count","min","max","mean","std"]]
# Out:
#                             count   min   max       mean        std
# race               sex
# Amer-Indian-Eskimo Female    66.0  17.0  60.0  34.651515  12.266894
#                    Male      93.0  17.0  75.0  36.537634  11.005492
# Asian-Pac-Islander Female   171.0  18.0  81.0  36.807018  13.255993
#                    Male     309.0  18.0  90.0  38.815534  12.710371
# Black              Female   753.0  17.0  73.0  38.013280  12.945460
#                    Male     808.0  17.0  81.0  38.388614  13.327352
# Other              Female    46.0  17.0  64.0  30.108696  10.263697
#                    Male      89.0  18.0  67.0  36.101124  12.603251
# White              Female  4385.0  17.0  90.0  37.023489  14.698216
#                    Male    9561.0  17.0  90.0  39.808807  13.553669

# %% [markdown]
# From above 2 cells, the maximum age of men of Amer-Indian-Eskimo race is 75

# %%
x = Input.loc[Input["class"] == ">50K."].copy()
x
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 2       28         Local-gov  336951    Assoc-acdm             12
# 3       44           Private  160323  Some-college             10
# 7       63  Self-emp-not-inc  104626   Prof-school             15
# 10      65           Private  184454       HS-grad              9
# 14      48           Private  279724       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 16254   38           Private  149347       Masters             14
# 16255   43         Local-gov   23157       Masters             14
# 16261   40           Private  202168   Prof-school             15
# 16265   50         Local-gov  139347       Masters             14
# 16280   35      Self-emp-inc  182148     Bachelors             13
#
#            marital_status         occupation relationship   race     sex  \
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# ...

# %%
x.groupby(["class","marital_status"])["marital_status"].describe()[["count"]]
# Out:
#                             count
# class marital_status
# >50K. Divorced                208
#       Married-AF-spouse         4
#       Married-civ-spouse     3292
#       Married-spouse-absent    24
#       Never-married           242
#       Separated                33
#       Widowed                  43

# %%
check =["Married-civ-spouse"]
k =Input[Input["class"]==">50K."]["marital_status"].isin(check).value_counts()
if k[True]>k[False]:
    print("married")
else:
    print("bachelors")
# Out:
# married

# %%
Input["hours_per_week"].max()
# Out:
# 99

# %%
Input["hours_per_week"].value_counts()[99]
# Out:
# 52

# %%
Input[["native_country","class","hours_per_week"]].groupby(["native_country","class"]).agg(["count","mean"])
# Out:
#                       hours_per_week
#                                count       mean
# native_country class
# Cambodia       <=50K.              7  40.714286
#                >50K.               2  57.500000
# Canada         <=50K.             37  36.189189
#                >50K.              24  46.916667
# China          <=50K.             31  35.451613
# ...                              ...        ...
# United-States  >50K.            3523  45.403633
# Vietnam        <=50K.             17  40.235294
#                >50K.               2  40.000000
# Yugoslavia     <=50K.              5  32.400000
#                >50K.               2  25.000000
#
# [76 rows x 2 columns]

# %%
Input.groupby("native_country")["hours_per_week"].mean()
# Out:
# native_country
# Cambodia                      44.444444
# Canada                        40.409836
# China                         39.021277
# Columbia                      41.884615
# Cuba                          42.186047
# Dominican-Republic            39.818182
# Ecuador                       38.764706
# El-Salvador                   35.428571
# England                       42.189189
# France                        35.444444
# Germany                       40.420290
# Greece                        50.750000
# Guatemala                     37.333333
# Haiti                         36.935484
# Honduras                      34.428571
# Hong                          39.000000
# Hungary                       43.000000
# India                         41.215686
# Iran                          40.187500
# Ireland                       42.461538
# Italy                         39.437500
# Jamaica                       41.000000
# Japan                         39.366667
# ...

# %%
Input.groupby("native_country")["hours_per_week"].mean()["Japan"]
# Out:
# 39.36666666666667

# %%
Input.groupby("native_country")["hours_per_week"].mean()["Taiwan"]
# Out:
# 41.285714285714285

# %%
Input["relationship"].value_counts()
# Out:
# Husband           6523
# Not-in-family     4278
# Own-child         2513
# Unmarried         1679
# Wife               763
# Other-relative     525
# Name: relationship, dtype: int64

# %%
Input["relationship"].value_counts()["Husband"]
# Out:
# 6523
